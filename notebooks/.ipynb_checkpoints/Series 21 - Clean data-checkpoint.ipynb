# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../data/raw/TM Series 21 only.csv")

# %%
# Quick check
print(df.head())

# list all columns
df.columns.tolist()
# Out:
#    Series        Contestant  Score After Ep 1  PPT Score After Ep 1
# 0      21      Amy Gledhill                16                   3.2
# 1      21  Armando Iannucci                11                   2.2
# 2      21       Joanna Page                22                   4.4
# 3      21      Joel Dommett                11                   2.2
# 4      21   Kumail Nanjiani                 9                   1.8
# ['Series', 'Contestant', 'Score After Ep 1', 'PPT Score After Ep 1']

# %%
# rename columns to work better in code
df_model = df.rename(columns={
    "Score After Ep 1": "score_ep1",
    "PPT Score After Ep 1": "ppt_ep1"})

df_model.head()
# Out:
#    Series        Contestant  score_ep1  ppt_ep1
# 0      21      Amy Gledhill         16      3.2
# 1      21  Armando Iannucci         11      2.2
# 2      21       Joanna Page         22      4.4
# 3      21      Joel Dommett         11      2.2
# 4      21   Kumail Nanjiani          9      1.8

# %%
# Basic data checks for nulls and data types
df_model.info()

df_model.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Series      5 non-null      int64
#  1   Contestant  5 non-null      object
#  2   score_ep1   5 non-null      int64
#  3   ppt_ep1     5 non-null      float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 288.0+ bytes
# Series        0
# Contestant    0
# score_ep1     0
# ppt_ep1       0
# dtype: int64

# %%
df_model.to_csv('../data/processed/S21_E1_cleaned_data.csv', index=False)
print("Prepared data set saved to data/processed/S21_E1_cleaned_data.csv")
# Out:
# Prepared data set saved to data/processed/S21_E1_cleaned_data.csv
